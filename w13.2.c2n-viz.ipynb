# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

url = "https://raw.githubusercontent.com/nkmwicz/data-for-students/refs/heads/main/imdb.csv"

df = pd.read_csv(url)
df.head(1)
# Out:
#    Unnamed: 0  Rank                    Title                    Genre  \
# 0           0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating  ...  Drama  Music  Biography  Romance  History  Crime  Western  \
# 0     8.1  ...  False  False      False    False    False  False    False
#
#      War  Musical  Sport
# 0  False    False  False
#
# [1 rows x 33 columns]

# %%
# df.to_csv("./data/imdb.csv", index=False)

# %%
# for item in unique_items:
#     df[item] = df["Genre"].apply(lambda x: item in x)

# %%
plt.figure(figsize=(8,5))
bar = sns.barplot(data=df, x="Year", y="Rating")

# %%
years = sorted(df["Year"].unique())
samples = [df.loc[df["Year"] == y, "Rating"] for y in years]
f, p = stats.f_oneway(*samples)
dfb = len(samples) - 1
dfw = len(df) - len(samples)
alpha = 0.05
cf = stats.f.ppf(1 - alpha, dfb, dfw)
print(f"f:{f:.4f}, crit_f:{cf:.4f}, p:{p:.4f}")
# Out:
# f:6.0455, crit_f:1.8403, p:0.0000

# %%
tukey = stats.tukey_hsd(*samples)
print(tukey)
print(years)
# Out:
# Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.009     1.000    -0.616     0.598
#  (0 - 2)      0.340     0.779    -0.269     0.950
#  (0 - 3)      0.164     0.999    -0.448     0.777
#  (0 - 4)      0.298     0.870    -0.292     0.889
#  (0 - 5)      0.287     0.889    -0.298     0.872
#  (0 - 6)      0.200     0.991    -0.383     0.783
#  (0 - 7)      0.313     0.751    -0.234     0.859
#  (0 - 8)      0.287     0.827    -0.253     0.827
#  (0 - 9)      0.523     0.048     0.002     1.043
#  (0 - 10)      0.688     0.000     0.208     1.169
#  (1 - 0)      0.009     1.000    -0.598     0.616
#  (1 - 2)      0.349     0.690    -0.232     0.930
#  (1 - 3)      0.173     0.997    -0.411     0.757
#  (1 - 4)      0.307     0.799    -0.254     0.868
#  (1 - 5)      0.296     0.825    -0.259     0.851
#  (1 - 6)      0.209     0.980    -0.344     0.762
#  (1 - 7)      0.322     0.635    -0.192     0.836
#  (1 - 8)      0.296     0.728    -0.211     0.804
#  (1 - 9)      0.532     0.019     0.045     1.018
#  (1 - 10)      0.697     0.000     0.254     1.141
#  (2 - 0)     -0.340     0.779    -0.950     0.269
#  (2 - 1)     -0.349     0.690    -0.930     0.232
#  (2 - 3)     -0.176     0.997    -0.763     0.410
#  (2 - 4)     -0.042     1.000    -0.606     0.522
#  (2 - 5)     -0.053     1.000    -0.611     0.504
#  (2 - 6)     -0.140     0.999    -0.696     0.415
#  (2 - 7)     -0.027     1.000    -0.545     0.490
#  (2 - 8)     -0.053     1.000    -0.564     0.457
#  (2 - 9)      0.182     0.982    -0.308     0.672
#  (2 - 10)      0.348     0.300    -0.099     0.795
#  (3 - 0)     -0.164     0.999    -0.777     0.448
#  (3 - 1)     -0.173     0.997    -0.757     0.411
#  (3 - 2)      0.176     0.997    -0.410     0.763
#  (3 - 4)      0.134     1.000    -0.433     0.701
#  (3 - 5)      0.123     1.000    -0.438     0.683
#  (3 - 6)      0.036     1.000    -0.523     0.594
#  (9 - 4)     -0.224     0.901    -0.691     0.242
#  (9 - 5)     -0.236     0.856    -0.694     0.223
#  (9 - 6)     -0.323     0.447    -0.779     0.134
#  (9 - 7)     -0.210     0.858    -0.618     0.199
#  (9 - 8)     -0.235     0.719    -0.636     0.165
#  (9 - 10)      0.166     0.839    -0.150     0.481
#  (10 - 0)     -0.688     0.000    -1.169    -0.208
#  (10 - 1)     -0.697     0.000    -1.141    -0.254
#  (10 - 2)     -0.348     0.300    -0.795     0.099
#  (10 - 3)     -0.524     0.009    -0.975    -0.073
#  (10 - 4)     -0.390     0.099    -0.811     0.031
#  (10 - 5)     -0.401     0.065    -0.814     0.011
#  (10 - 6)     -0.488     0.006    -0.898    -0.078
#  (10 - 7)     -0.375     0.029    -0.732    -0.019
#  (10 - 8)     -0.401     0.009    -0.748    -0.054
#  (10 - 9)     -0.166     0.839    -0.481     0.150
#
# [np.int64(2006), np.int64(2007), np.int64(2008), np.int64(2009), np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016)]

# %%
tukey = pairwise_tukeyhsd(
    endog=df["Rating"], # numeric values
    groups=df["Year"],
    alpha=0.05
)
tukey.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
plt.figure(figsize=(8,5))
bar = sns.barplot(data=df, x="Year", y="Rating", hue="Animation")

# %%
animated, non_animated = [
    df.loc[df["Animation"] == b, "Rating"] for b in [True, False]
    ]
t, p = stats.ttest_ind(animated, non_animated)
deg_f = len(animated) + len(non_animated) - 2
ct = stats.t.ppf(1-alpha/2, deg_f)
text = f"""t={t:.4f}
critical={ct:.4f}
p={p:.4f}"""

# %%
plt.figure(figsize=(8,5))
box = sns.boxplot(data=df, x="Year", y="Rating", hue="Animation")
box.text(x=0.5, y=0.2, s=text, transform=box.transAxes)
# Out:
# Text(0.5, 0.2, 't=4.6113\ncritical=1.9623\np=0.0000')

# %%
# act, adv, scifi
# drama
# comedy, romance
# animation, adv, comedy
g1 = df.loc[(df["Action"] == True) | (df["Adventure"] == True) | (df["Sci-Fi"] == True)]
s1 = {"l"}
s2 = {"l", "o"}
print(bool(s1 & s2))
s1 & s2
# Out:
# True
# {'l'}

# %%
groups = [
    ["Action", "Adventure", "Sci-Fi"],
    ["Drama"],
    ["Comedy", "Romance"],
    ["Animation", "Adventure", "Comedy"]
]
df["Genre"] = df["Genre"].str.split(",")
df["Genre"]
# Out:
# 0       [Action, Adventure, Sci-Fi]
# 1      [Adventure, Mystery, Sci-Fi]
# 2                [Horror, Thriller]
# 3       [Animation, Comedy, Family]
# 4      [Action, Adventure, Fantasy]
#                    ...
# 995         [Crime, Drama, Mystery]
# 996                        [Horror]
# 997         [Drama, Music, Romance]
# 998             [Adventure, Comedy]
# 999       [Comedy, Family, Fantasy]
# Name: Genre, Length: 1000, dtype: object

# %%
samples = [df.loc[df["Genre"].apply(lambda x: bool(set(x) & set(g))), "Rating"] for g in groups]
f, p = stats.f_oneway(*samples)
dfb = len(samples) - 1
dfw = sum([len(s) for s in samples]) - len(samples)
cf = stats.f.ppf(1-alpha, dfb, dfw)
text = f"""f={f:.4f}
crit_f={cf:.4f}
p={p:.4f}"""

heights = [s.mean() for s in samples]
cols = ["/".join([item[:3] for item in g]) for g in groups]
plt.figure(figsize=(8,5))
plt.bar(x=cols, height=heights)
plt.text(x=0.1, y=1.05, s=text, transform=plt.gca().transAxes)
plt.show()
